# %% [markdown]
# <a href="https://colab.research.google.com/github/farisikhhaq/PCVK_2022/blob/master/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/PCVK_MM/image/kitten01.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F90D5666150>

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/image/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK_MM/')

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))  #ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax. imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 ptl dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,
           color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai untuk menunjukan bahwa tiap titik dibuat 3 channel yang memiliki R, G dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
#  **TUGAS**

# %%
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
img_gb = img.copy()
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
img_k = img[10:100,10:100]
plt.imshow(img_k)

# %%
imgcolorGB = cv.cvtColor(img,cv.COLOR_BGR2RGB)

cv.rectangle(imgcolorGB, pt1=(150,75), pt2=(110,25), color=(0,255,0), thickness=1)
cv.rectangle(imgcolorGB, pt1=(75,125), pt2=(100,175), color=(255,255,0), thickness=1)
cv.rectangle(imgcolorGB, pt1=(60,75), pt2=(90,25), color=(0,255,0), thickness=1)
cv.rectangle(imgcolorGB, pt1=(110,175), pt2=(140,130), color=(255,255,0), thickness=1)
cv.rectangle(imgcolorGB, pt1=(120,50), pt2=(75,80), color=(0,255,255), thickness=1)

plt.imshow(imgcolorGB)

# %%
img_flip=cv.flip(cv.cvtColor(imgcolorGB,cv.COLOR_BGR2RGB), 0)
plt.imshow(img_flip)

# %%
cv.rectangle(img, pt1=(75,50), pt2=(120,80), color=(0,255,255), thickness=1)
plt.imshow(img)

# %%
cv.circle(img,center=(95,60),radius=37,color=(255,0,0),thickness=1)
plt.imshow(img)

# %%
cv.rectangle(img_gb,pt1=(0,50),pt2=(30,45),color=(0,255,0),thickness=1)
plt.imshow(img_gb)
