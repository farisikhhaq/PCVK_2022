# %% [markdown]
# <a href="https://colab.research.google.com/github/farisikhhaq/PCVK_2022/blob/master/Week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nomor 1
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Nomor 2
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
from skimage import io
from skimage import transform
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.morphology import (erosion, dilation, closing, opening,
                                area_closing, area_opening)
from skimage.color import rgb2gray

# %%
#NOMOR 3
img = cv.imread('/content/drive/MyDrive/PCVK_MM/image/j.png')

kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f11c1808e50>,
#  <matplotlib.image.AxesImage at 0x7f11c17f3790>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#NOMOR 4
img1= cv.imread('/content/drive/MyDrive/PCVK_MM/image/j.png', 0)

m,n= img1.shape 

plt.imshow(img1, cmap="gray")

k=5
SE= np.ones((k,k), dtype=np.uint8)
constant= (k-1)//2

imgErode= np.zeros((m,n), dtype=np.uint8)

for i in range(constant, m-constant):
  for j in range(constant,n-constant):
    temp= img1[i-constant:i+constant+1, j-constant:j+constant+1]
    product= temp*SE
    imgErode[i,j]= np.min(product)
plt.subplot(121), plt.imshow(img1, cmap ="gray"), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(imgErode, cmap="gray"), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8905b109d0>,
#  <matplotlib.image.AxesImage at 0x7f8905af0290>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %% [markdown]
# /content/drive/MyDrive/PCVK_MM/image/j.png

# %%
#NOMER 4 LIBLARY
imgcek= cv.imread('/content/drive/MyDrive/PCVK_MM/image/j.png', 0)
kernel = np.ones((5,5), np.uint8)
erosion = cv.erode(imgcek, kernel, iterations = 1)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0ca59ef110>,
#  <matplotlib.image.AxesImage at 0x7f0ca59c2950>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
#NOMOR 5
kernel = np.ones((5,5), np.uint8)
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f892787f590>,
#  <matplotlib.image.AxesImage at 0x7f8905a35290>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#NOMOR 6
kernel = np.ones((5,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f89059a8350>,
#  <matplotlib.image.AxesImage at 0x7f8905910d90>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
#NOMOR 7
kernel = np.ones((7,7), np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f89059c4550>,
#  <matplotlib.image.AxesImage at 0x7f8905875110>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %%
#NOMOR 8
kernel = np.ones((7,7), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Citra Hasil')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f89057fad10>,
#  <matplotlib.image.AxesImage at 0x7f89057515d0>,
#  Text(0.5, 1.0, 'Citra Hasil'))

# %%
#NOMOR 9
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f89056d9450>,
#  <matplotlib.image.AxesImage at 0x7f89056a5c90>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 3x3'))

# %%
#NOMOR 9 5x5 Pixel
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f11c17f3cd0>,
#  <matplotlib.image.AxesImage at 0x7f11c123a590>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 3x3'))

# %%
#NOMOR 10
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Circular 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8905634550>,
#  <matplotlib.image.AxesImage at 0x7f89055fdd50>,
#  Text(0.5, 1.0, 'Citra Hasil Circular 3x3'))

# %%
#NOMOR 11
kernel = cv.getStructuringElement(cv.MORPH_RECT, (3, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 3x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0ca5cbebd0>,
#  <matplotlib.image.AxesImage at 0x7f0ca5c95450>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 3x5'))

# %%
#NOMOR 11
kernel = cv.getStructuringElement(cv.MORPH_RECT, (5, 7))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 5x7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0ca5ce8710>,
#  <matplotlib.image.AxesImage at 0x7f0ca5cb30d0>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 5x7'))

# %%
#NOMOR 12
kernel = cv.getStructuringElement(cv.MORPH_RECT, (5, 7))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 5x7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0ca5b57d50>,
#  <matplotlib.image.AxesImage at 0x7f0ca5aaa610>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 5x7'))
